# %%
import sys; sys.path.insert(0, "/teamspace/studios/this_studio")
# %matplotlib inline
from src import config, data, utils, eda_utils
eda_utils.setup_eda_style()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import sys; sys.path.insert(0, "/teamspace/studios/this_studio")
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 3 from src import config, data, utils, eda_utils
#       4 eda_utils.setup_eda_style()
#
# File ~/src/eda_utils.py:14
#      12 import matplotlib.pyplot as plt
#      13 import pandas as pd
# ---> 14 import seaborn as sns
#      15 from matplotlib.axes import Axes
#      16 from matplotlib.figure import Figure
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# !uv pip install seaborn
# Out:
# Using Python 3.11.15 environment at: /teamspace/studios/this_studio/.venv
# ⠙ Resolving dependencies...
# ⠙ python-dateutil==2.9.0.post0
# Resolved 13 packages in 163ms
# Installed 1 package in 21ms
#  + seaborn==0.13.2
